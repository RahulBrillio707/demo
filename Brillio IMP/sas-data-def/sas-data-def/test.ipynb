# %%
code=r"""/* ============================================================= */
/* Extended SAS script for Customer Segmentation & Enrichment    */
/* ============================================================= */

/* Global macro variable for threshold */
# %let seg_threshold = 1000;

/* Step 1: Import and clean customer data */
data customers_clean;
    set raw.customer_data;
    where status = 'ACTIVE';
    total_spend = sum(spend_cat1, spend_cat2, spend_cat3);
    if total_spend < 0 then total_spend = 0;
    if missing(region) then region = 'UNKNOWN';
    format join_date date9.;
run;

/* Step 1a: Import transaction data */
data transactions_clean;
    set raw.transaction_data;
    where txn_status = 'SUCCESS';
    txn_month = month(txn_date);
    txn_year  = year(txn_date);
    if amount < 0 then amount = 0;
run;

/* Step 1b: Import loyalty program data */
data loyalty_clean;
    set raw.loyalty_data;
    where enrolled = 1;
    if missing(loyalty_points) then loyalty_points = 0;
run;

/* Step 2: Merge customer and transaction data */
proc sql;
    create table customer_txn_summary as
    select 
        a.customer_id,
        a.region,
        a.total_spend,
        count(distinct b.txn_id) as txn_count,
        sum(b.amount) as txn_total,
        avg(b.amount) as avg_txn_amount
    from customers_clean a
    left join transactions_clean b
        on a.customer_id = b.customer_id
    group by a.customer_id, a.region, a.total_spend;
quit;

/* Step 2a: Merge with loyalty data */
proc sql;
    create table customer_full_profile as
    select 
        c.*,
        l.loyalty_points,
        case 
            when l.loyalty_points >= 5000 then 'GOLD'
            when l.loyalty_points >= 1000 then 'SILVER'
            else 'BRONZE'
        end as loyalty_tier
    from customer_txn_summary c
    left join loyalty_clean l
        on c.customer_id = l.customer_id;
quit;

/* Step 3: Create customer segments */
proc sql;
    create table customer_segments as
    select 
        customer_id,
        region,
        total_spend,
        txn_total,
        loyalty_tier,
        case 
            when total_spend > &seg_threshold then 'HIGH'
            when total_spend > (&seg_threshold/2) then 'MEDIUM'
            else 'LOW'
        end as spend_segment,
        count(*) as segment_size
    from customer_full_profile
    group by calculated spend_segment, region, loyalty_tier
    order by region, loyalty_tier, calculated spend_segment;
quit;

/* Step 4: Create summary report */
proc summary data=customer_segments nway;
    class region spend_segment loyalty_tier;
    var total_spend txn_total;
    output out=segment_summary
           sum(total_spend txn_total)=total_segment_revenue total_txn_revenue
           mean(total_spend txn_total)=avg_customer_spend avg_txn_value;
run;

/* Step 5: Define report formatting macro */
# %macro format_report(input_ds, output_ds, title_text);
    data &output_ds;
        set &input_ds;
        report_title = "&title_text";
        report_date = today();
        format report_date date9.;
        if total_segment_revenue > 100000 then highlight = 'YES';
        else highlight = 'NO';
    run;

    proc print data=&output_ds;
        title "&title_text";
        var region spend_segment loyalty_tier 
            total_segment_revenue total_txn_revenue 
            avg_customer_spend avg_txn_value highlight;
    run;
# %mend;

/* Step 6: Generate formatted report */
# %format_report(segment_summary, final_report, Customer Segment Analysis with Loyalty & Transactions);

/* Step 7: Export results */
proc export data=final_report
    outfile="segment_analysis_extended.xlsx"
    dbms=xlsx
    replace;
run;"""

# %%
import time
from sas_parser import parse_sas_code

start_time = time.time()

def is_container_field(key, value):
    """Check if a field contains nested SAS constructs"""
    if not isinstance(value, (list, dict)):
        return False

    # Skip metadata fields
    skip_fields = {'location', 'comments', 'errors', 'options', 'arguments'}
    if key in skip_fields:
        return False

    # Check if it's a list of objects with 'type' field
    if isinstance(value, list):
        return any(isinstance(item, dict) and 'type' in item for item in value)

    # Check if it's a dict with 'type' field or contains nested structures
    if isinstance(value, dict):
        if 'type' in value:
            return True
        # Check if any values in the dict are lists of constructs
        return any(is_container_field(k, v) for k, v in value.items())

    return False

def analyze_structure(items, indent=0, discovered_containers=None):
    if discovered_containers is None:
        discovered_containers = set()

    # Handle both list and single item
    if not isinstance(items, list):
        items = [items] if items else []

    for item in items:
        if not isinstance(item, dict):
            continue

        item_type = item.get('type', 'Unknown')
        name = item.get('macro_name', item.get('name', item.get('procedure_name', 'unnamed')))

        prefix = "  " * indent
        print(f'{prefix}• {item_type}: {name}')

        # Dynamically discover container fields
        for key, value in item.items():
            if is_container_field(key, value):
                discovered_containers.add(key)

                if isinstance(value, list) and value:
                    print(f'{prefix}  └─ {key} ({len(value)} items):')
                    analyze_structure(value, indent + 2, discovered_containers)
                elif isinstance(value, dict):
                    print(f'{prefix}  └─ {key} (dict):')
                    analyze_structure([value], indent + 2, discovered_containers)

    return discovered_containers

try:
    result = parse_sas_code(code, "nested_test.sas")
    end_time = time.time()

    print(f'✅ Parse completed in {end_time - start_time:.4f} seconds')
    print(f'📊 Body items: {len(result.get("body", []))}')

    print("\n🌳 Parsed Structure:")
    discovered_containers = analyze_structure(result.get('body', []))

    print(f"\n🔍 Discovered Container Fields:")
    for container in sorted(discovered_containers):
        print(f"   • {container}")

    # Look for any parsing issues in the debug output above
    print(f"\n🔍 Check the debug output above for:")
    print(f"   • Context push/pop messages")
    print(f"   • Any WARNING or ERROR messages")
    print(f"   • Proper nesting validation")


except Exception as e:
    end_time = time.time()
    print(f'❌ ERROR after {end_time - start_time:.4f} seconds: {e}')
    import traceback
    traceback.print_exc()

print("="*70)
# Out:
# [DEBUG] parse_module started at pos 0/465
# [DEBUG] Parsing LET statement at pos 0
# [DEBUG] Parsing DATA step at pos 5
# [DEBUG] parse_unknown_statement at pos 13, token: where
# [DEBUG] parse_unknown_statement completed, advanced to pos 18
# [DEBUG] parse_unknown_statement at pos 48, token: format
# [DEBUG] parse_unknown_statement completed, advanced to pos 53
# [DEBUG] Parsing DATA step at pos 55
# [DEBUG] parse_unknown_statement at pos 63, token: where
# [DEBUG] parse_unknown_statement completed, advanced to pos 68
# [DEBUG] Parsing DATA step at pos 93
# [DEBUG] parse_unknown_statement at pos 101, token: where
# [DEBUG] parse_unknown_statement completed, advanced to pos 106
# [DEBUG] Parsing PROC step at pos 118
# [DEBUG] Starting PROC sql statement parsing at pos 121
# [DEBUG] Calling parse_proc_sql_statement for SQL at pos 121
# [DEBUG] SQL statement parsed successfully, now at pos 194
# [DEBUG] Parsing PROC step at pos 196
# [DEBUG] Starting PROC sql statement parsing at pos 199
# [DEBUG] Calling parse_proc_sql_statement for SQL at pos 199
# [DEBUG] SQL statement parsed successfully, now at pos 250
# [DEBUG] Parsing PROC step at pos 252
# [DEBUG] Starting PROC sql statement parsing at pos 255
# [DEBUG] Calling parse_proc_sql_statement for SQL at pos 255
# [DEBUG] SQL statement parsed successfully, now at pos 320
# [DEBUG] Parsing PROC step at pos 322
# [DEBUG] Starting PROC summary statement parsing at pos 329
# [DEBUG] Parsing MACRO def at pos 361
# [DEBUG] Pushed MACRO context, expecting %MEND at pos 371
# [DEBUG] Parsing DATA step in macro at pos 371
# [DEBUG] parse_unknown_statement at pos 392, token: format
# [DEBUG] parse_unknown_statement completed, advanced to pos 397
# [DEBUG] Parsing PROC step in macro at pos 413
# [DEBUG] Starting PROC print statement parsing at pos 420
# [DEBUG] Correctly matched MACRO with %MEND at pos 438
# [DEBUG] Iteration 10, pos 440/465, token: '%format_report', type: 81
# [DEBUG] Parsing MACRO_IDENTIFIER as macro call at pos 440
# [DEBUG] Parsing PROC step at pos 449
# [DEBUG] Starting PROC export statement parsing at pos 462
# [DEBUG] parse_module completed. Body items: 11
# ✅ Parse completed in 0.0025 seconds
# 📊 Body items: 11
#
# 🌳 Parsed Structure:
# • SasLetStatement: seg_threshold
# • SasDataStep: customers_clean
#   └─ statements (6 items):
#     • SasSetStatement: unnamed
#       └─ datasets (1 items):
#         • SasDatasetRef: raw.customer_data
#     • SasUnknownStatement: unnamed
#     • SasAssignmentStatement: unnamed
#     • SasIfStatement: unnamed
#       └─ then_block (dict):
#         • SasAssignmentStatement: unnamed
#     • SasIfStatement: unnamed
#       └─ then_block (dict):
#         • SasAssignmentStatement: unnamed
#     • SasUnknownStatement: unnamed
# • SasDataStep: transactions_clean
#   └─ statements (5 items):
#     • SasSetStatement: unnamed
#       └─ datasets (1 items):
#         • SasDatasetRef: raw.transaction_data
#     • SasUnknownStatement: unnamed
#     • SasAssignmentStatement: unnamed
#     • SasAssignmentStatement: unnamed
#     • SasIfStatement: unnamed
#       └─ then_block (dict):
#         • SasAssignmentStatement: unnamed
# • SasDataStep: loyalty_clean
#   └─ statements (3 items):
#     • SasSetStatement: unnamed
#       └─ datasets (1 items):
#         • SasDatasetRef: raw.loyalty_data
#     • SasUnknownStatement: unnamed
#     • SasIfStatement: unnamed
#       └─ then_block (dict):
#         • SasAssignmentStatement: unnamed
# • SasProcStep: sql
#   └─ statements (1 items):
#     • SasProcSqlCreateTableStatement: unnamed
#       └─ select_statement (dict):
#         • SasProcSqlSelectStatement: unnamed
#           └─ columns (6 items):
#             • SasSimpleColumn: unnamed
#             • SasSimpleColumn: unnamed
#             • SasSimpleColumn: unnamed
#             • SasSimpleColumn: unnamed
#             • SasSimpleColumn: unnamed
#             • SasSimpleColumn: unnamed
#           └─ from (dict):
#             • SasProcSqlFromClause: unnamed
#               └─ main_table (dict):
#                 • SasProcSqlTableRef: unnamed
#               └─ joins (1 items):
#                 • SasProcSqlJoin: unnamed
#                   └─ table (dict):
#                     • SasProcSqlTableRef: unnamed
#                   └─ on_condition (dict):
#                     • SasProcSqlJoinCondition: unnamed
#           └─ group_by (dict):
#             • SasProcSqlGroupByClause: unnamed
# • SasProcStep: sql
#   └─ statements (1 items):
#     • SasProcSqlCreateTableStatement: unnamed
#       └─ select_statement (dict):
#         • SasProcSqlSelectStatement: unnamed
#           └─ columns (3 items):
#             • SasCalculatedColumn: unnamed
#             • SasSimpleColumn: unnamed
#             • SasCaseColumn: unnamed
#           └─ from (dict):
#             • SasProcSqlFromClause: unnamed
#               └─ main_table (dict):
#                 • SasProcSqlTableRef: unnamed
#               └─ joins (1 items):
#                 • SasProcSqlJoin: unnamed
#                   └─ table (dict):
#                     • SasProcSqlTableRef: unnamed
#                   └─ on_condition (dict):
#                     • SasProcSqlJoinCondition: unnamed
# • SasProcStep: sql
#   └─ statements (1 items):
#     • SasProcSqlCreateTableStatement: unnamed
#       └─ select_statement (dict):
#         • SasProcSqlSelectStatement: unnamed
#           └─ columns (7 items):
#             • SasSimpleColumn: unnamed
#             • SasSimpleColumn: unnamed
#             • SasSimpleColumn: unnamed
#             • SasSimpleColumn: unnamed
#             • SasSimpleColumn: unnamed
#             • SasCaseColumn: unnamed
#             • SasCalculatedColumn: unnamed
#           └─ from (dict):
#             • SasProcSqlFromClause: unnamed
#               └─ main_table (dict):
#                 • SasProcSqlTableRef: unnamed
#           └─ group_by (dict):
#             • SasProcSqlGroupByClause: unnamed
#           └─ order_by (dict):
#             • SasProcSqlOrderByClause: unnamed
# • SasProcStep: summary
#   └─ statements (1 items):
#     • SasProcVarStatement: unnamed
# • SasMacroDef: format_report
#   └─ macro_body (2 items):
#     • SasDataStep: unnamed
#       └─ statements (5 items):
#         • SasSetStatement: unnamed
#         • SasAssignmentStatement: unnamed
#         • SasAssignmentStatement: unnamed
#         • SasUnknownStatement: unnamed
#         • SasIfStatement: unnamed
#           └─ then_block (dict):
#             • SasAssignmentStatement: unnamed
#           └─ else_block (dict):
#             • SasAssignmentStatement: unnamed
#     • SasProcStep: print
#       └─ statements (1 items):
#         • SasProcVarStatement: unnamed
# • SasMacroCall: format_report
# • SasProcStep: export
#
# 🔍 Discovered Container Fields:
#    • columns
#    • datasets
#    • else_block
#    • from
#    • group_by
#    • joins
#    • macro_body
#    • main_table
#    • on_condition
#    • order_by
#    • select_statement
#    • statements
#    • table
#    • then_block
#
# 🔍 Check the debug output above for:
#    • Context push/pop messages
#    • Any WARNING or ERROR messages
#    • Proper nesting validation
# ======================================================================

# %%
result
# Out:
# {'id': 'node_000001',
#  'level': 0,
#  'location': {'file': 'nested_test.sas',
#   'line_start': 1,
#   'col_start': 0,
#   'line_end': 122,
#   'col_end': 4,
#   'byte_start': 0,
#   'byte_end': 3676},
#  'comments': ['/* ============================================================= */',
#   '/* Extended SAS script for Customer Segmentation & Enrichment    */',
#   '/* ============================================================= */',
#   '/* Global macro variable for threshold */',
#   '/* Step 1: Import and clean customer data */',
#   '/* Step 1a: Import transaction data */',
#   '/* Step 1b: Import loyalty program data */',
#   '/* Step 2: Merge customer and transaction data */',
#   '/* Step 2a: Merge with loyalty data */',
#   '/* Step 3: Create customer segments */',
#   '/* Step 4: Create summary report */',
#   '/* Step 5: Define report formatting macro */',
#   '/* Step 6: Generate formatted report */',
#   '/* Step 7: Export results */'],
#  'type': 'SasModule',
#  'encoding': None,
#  'includes': [],
#  'options_snapshot': {},
#  'symbol_table': {},
#  'body': [{'id': 'node_000002',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 6,
#     'col_start': 0,
#     'line_end': 6,
#     'col_end': 26,
#     'byte_start': 247,
#     'byte_end': 273},
#    'comments': ['/* Global macro variable for threshold */'],
#    'type': 'SasLetStatement',
#    'name': 'seg_threshold',
#    'value': '1000',
#    'is_global': None},
#   {'id': 'node_000011',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 9,
#     'col_start': 0,
#     'line_end': 16,
#     'col_end': 4,
#     'byte_start': 320,
#     'byte_end': 583},
#    'comments': ['/* Step 1: Import and clean customer data */'],
#    'type': 'SasDataStep',
#    'name': 'customers_clean',
#    'datasets_out': ['customers_clean'],
#    'statements': [{'id': 'node_000003',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 10,
#       'col_start': 4,
#       'line_end': 10,
#       'col_end': 26,
#       'byte_start': 346,
#       'byte_end': 368},
#      'type': 'SasSetStatement',
#      'datasets': [{'type': 'SasDatasetRef',
#        'name': 'raw.customer_data',
#        'options': {}}]},
#     {'id': 'node_000004',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 11,
#       'col_start': 4,
#       'line_end': 11,
#       'col_end': 28,
#       'byte_start': 373,
#       'byte_end': 397},
#      'type': 'SasUnknownStatement',
#      'kind': 'unknown',
#      'text': "wherestatus='ACTIVE';"},
#     {'id': 'node_000005',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 12,
#       'col_start': 4,
#       'line_end': 12,
#       'col_end': 58,
#       'byte_start': 402,
#       'byte_end': 456},
#      'type': 'SasAssignmentStatement',
#      'variable': 'total_spend',
#      'expression': 'sum ( spend_cat1 , spend_cat2 , spend_cat3 )'},
#     {'id': 'node_000007',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 13,
#       'col_start': 4,
#       'line_end': 13,
#       'col_end': 6,
#       'byte_start': 461,
#       'byte_end': 463},
#      'type': 'SasIfStatement',
#      'condition': 'total_spend < 0',
#      'then_block': {'id': 'node_000006',
#       'level': 0,
#       'location': {'file': 'nested_test.sas',
#        'line_start': 13,
#        'col_start': 28,
#        'line_end': 13,
#        'col_end': 44,
#        'byte_start': 485,
#        'byte_end': 501},
#       'type': 'SasAssignmentStatement',
#       'variable': 'total_spend',
#       'expression': '0'},
#      'else_block': None},
#     {'id': 'node_000009',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 14,
#       'col_start': 4,
#       'line_end': 14,
#       'col_end': 6,
#       'byte_start': 506,
#       'byte_end': 508},
#      'type': 'SasIfStatement',
#      'condition': 'missing ( region )',
#      'then_block': {'id': 'node_000008',
#       'level': 0,
#       'location': {'file': 'nested_test.sas',
#        'line_start': 14,
#        'col_start': 28,
#        'line_end': 14,
#        'col_end': 47,
#        'byte_start': 530,
#        'byte_end': 549},
#       'type': 'SasAssignmentStatement',
#       'variable': 'region',
#       'expression': "'UNKNOWN'"},
#      'else_block': None},
#     {'id': 'node_000010',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 15,
#       'col_start': 4,
#       'line_end': 15,
#       'col_end': 28,
#       'byte_start': 554,
#       'byte_end': 578},
#      'type': 'SasUnknownStatement',
#      'kind': 'unknown',
#      'text': 'formatjoin_datedate9.;'}]},
#   {'id': 'node_000018',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 19,
#     'col_start': 0,
#     'line_end': 25,
#     'col_end': 4,
#     'byte_start': 624,
#     'byte_end': 817},
#    'comments': ['/* Step 1a: Import transaction data */'],
#    'type': 'SasDataStep',
#    'name': 'transactions_clean',
#    'datasets_out': ['transactions_clean'],
#    'statements': [{'id': 'node_000012',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 20,
#       'col_start': 4,
#       'line_end': 20,
#       'col_end': 29,
#       'byte_start': 653,
#       'byte_end': 678},
#      'type': 'SasSetStatement',
#      'datasets': [{'type': 'SasDatasetRef',
#        'name': 'raw.transaction_data',
#        'options': {}}]},
#     {'id': 'node_000013',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 21,
#       'col_start': 4,
#       'line_end': 21,
#       'col_end': 33,
#       'byte_start': 683,
#       'byte_end': 712},
#      'type': 'SasUnknownStatement',
#      'kind': 'unknown',
#      'text': "wheretxn_status='SUCCESS';"},
#     {'id': 'node_000014',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 22,
#       'col_start': 4,
#       'line_end': 22,
#       'col_end': 32,
#       'byte_start': 717,
#       'byte_end': 745},
#      'type': 'SasAssignmentStatement',
#      'variable': 'txn_month',
#      'expression': 'month ( txn_date )'},
#     {'id': 'node_000015',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 23,
#       'col_start': 4,
#       'line_end': 23,
#       'col_end': 31,
#       'byte_start': 750,
#       'byte_end': 777},
#      'type': 'SasAssignmentStatement',
#      'variable': 'txn_year',
#      'expression': 'year ( txn_date )'},
#     {'id': 'node_000017',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 24,
#       'col_start': 4,
#       'line_end': 24,
#       'col_end': 6,
#       'byte_start': 782,
#       'byte_end': 784},
#      'type': 'SasIfStatement',
#      'condition': 'amount < 0',
#      'then_block': {'id': 'node_000016',
#       'level': 0,
#       'location': {'file': 'nested_test.sas',
#        'line_start': 24,
#        'col_start': 23,
#        'line_end': 24,
#        'col_end': 34,
#        'byte_start': 801,
#        'byte_end': 812},
#       'type': 'SasAssignmentStatement',
#       'variable': 'amount',
#       'expression': '0'},
#      'else_block': None}]},
#   {'id': 'node_000023',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 28,
#     'col_start': 0,
#     'line_end': 32,
#     'col_end': 4,
#     'byte_start': 862,
#     'byte_end': 992},
#    'comments': ['/* Step 1b: Import loyalty program data */'],
#    'type': 'SasDataStep',
#    'name': 'loyalty_clean',
#    'datasets_out': ['loyalty_clean'],
#    'statements': [{'id': 'node_000019',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 29,
#       'col_start': 4,
#       'line_end': 29,
#       'col_end': 25,
#       'byte_start': 886,
#       'byte_end': 907},
#      'type': 'SasSetStatement',
#      'datasets': [{'type': 'SasDatasetRef',
#        'name': 'raw.loyalty_data',
#        'options': {}}]},
#     {'id': 'node_000020',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 30,
#       'col_start': 4,
#       'line_end': 30,
#       'col_end': 23,
#       'byte_start': 912,
#       'byte_end': 931},
#      'type': 'SasUnknownStatement',
#      'kind': 'unknown',
#      'text': 'whereenrolled=1;'},
#     {'id': 'node_000022',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 31,
#       'col_start': 4,
#       'line_end': 31,
#       'col_end': 6,
#       'byte_start': 936,
#       'byte_end': 938},
#      'type': 'SasIfStatement',
#      'condition': 'missing ( loyalty_points )',
#      'then_block': {'id': 'node_000021',
#       'level': 0,
#       'location': {'file': 'nested_test.sas',
#        'line_start': 31,
#        'col_start': 36,
#        'line_end': 31,
#        'col_end': 55,
#        'byte_start': 968,
#        'byte_end': 987},
#       'type': 'SasAssignmentStatement',
#       'variable': 'loyalty_points',
#       'expression': '0'},
#      'else_block': None}]},
#   {'id': 'node_000034',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 35,
#     'col_start': 0,
#     'line_end': 48,
#     'col_end': 5,
#     'byte_start': 1044,
#     'byte_end': 1455},
#    'comments': ['/* Step 2: Merge customer and transaction data */'],
#    'type': 'SasProcStep',
#    'procedure_name': 'sql',
#    'options': {},
#    'statements': [{'id': 'node_000033',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 36,
#       'col_start': 4,
#       'line_end': 36,
#       'col_end': 10,
#       'byte_start': 1058,
#       'byte_end': 1064},
#      'type': 'SasProcSqlCreateTableStatement',
#      'table_name': 'customer_txn_summary',
#      'table_options': None,
#      'select_statement': {'id': 'node_000032',
#       'level': 0,
#       'location': {'file': 'nested_test.sas',
#        'line_start': 37,
#        'col_start': 4,
#        'line_end': 47,
#        'col_end': 52,
#        'byte_start': 1099,
#        'byte_end': 1449},
#       'type': 'SasProcSqlSelectStatement',
#       'distinct': False,
#       'columns': [{'id': 'node_000024',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 38,
#          'col_start': 8,
#          'line_end': 38,
#          'col_end': 22,
#          'byte_start': 1115,
#          'byte_end': 1129},
#         'type': 'SasSimpleColumn',
#         'expression': 'a . customer_id',
#         'alias': None,
#         'format': None,
#         'length': None,
#         'raw_tokens': ['a', '.', 'customer_id']},
#        {'id': 'node_000025',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 39,
#          'col_start': 8,
#          'line_end': 39,
#          'col_end': 17,
#          'byte_start': 1138,
#          'byte_end': 1147},
#         'type': 'SasSimpleColumn',
#         'expression': 'a . region',
#         'alias': None,
#         'format': None,
#         'length': None,
#         'raw_tokens': ['a', '.', 'region']},
#        {'id': 'node_000026',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 40,
#          'col_start': 8,
#          'line_end': 40,
#          'col_end': 22,
#          'byte_start': 1156,
#          'byte_end': 1170},
#         'type': 'SasSimpleColumn',
#         'expression': 'a . total_spend',
#         'alias': None,
#         'format': None,
#         'length': None,
#         'raw_tokens': ['a', '.', 'total_spend']},
#        {'id': 'node_000027',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 41,
#          'col_start': 8,
#          'line_end': 41,
#          'col_end': 46,
#          'byte_start': 1179,
#          'byte_end': 1217},
#         'type': 'SasSimpleColumn',
#         'expression': 'count ( distinct b . txn_id )',
#         'alias': 'txn_count',
#         'format': None,
#         'length': None,
#         'raw_tokens': ['count', '(', 'distinct', 'b', '.', 'txn_id', ')']},
#        {'id': 'node_000028',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 42,
#          'col_start': 8,
#          'line_end': 42,
#          'col_end': 35,
#          'byte_start': 1226,
#          'byte_end': 1253},
#         'type': 'SasSimpleColumn',
#         'expression': 'sum ( b . amount )',
#         'alias': 'txn_total',
#         'format': None,
#         'length': None,
#         'raw_tokens': ['sum', '(', 'b', '.', 'amount', ')']},
#        {'id': 'node_000029',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 43,
#          'col_start': 8,
#          'line_end': 44,
#          'col_end': 8,
#          'byte_start': 1262,
#          'byte_end': 1302},
#         'type': 'SasSimpleColumn',
#         'expression': 'avg ( b . amount )',
#         'alias': 'avg_txn_amount',
#         'format': None,
#         'length': None,
#         'raw_tokens': ['avg', '(', 'b', '.', 'amount', ')']}],
#       'into': None,
#       'from': {'id': 'node_000030',
#        'level': 0,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 44,
#         'col_start': 4,
#         'line_end': 44,
#         'col_end': 8,
#         'byte_start': 1298,
#         'byte_end': 1302},
#        'type': 'SasProcSqlFromClause',
#        'main_table': {'type': 'SasProcSqlTableRef',
#         'table_name': 'customers_clean',
#         'alias': 'a'},
#        'joins': [{'type': 'SasProcSqlJoin',
#          'join_type': 'LEFT',
#          'table': {'type': 'SasProcSqlTableRef',
#           'table_name': 'transactions_clean',
#           'alias': 'b'},
#          'on_condition': {'type': 'SasProcSqlJoinCondition',
#           'condition': 'a . customer_id = b . customer_id'}}]},
#       'where': None,
#       'group_by': {'id': 'node_000031',
#        'level': 0,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 47,
#         'col_start': 4,
#         'line_end': 47,
#         'col_end': 52,
#         'byte_start': 1401,
#         'byte_end': 1449},
#        'type': 'SasProcSqlGroupByClause',
#        'columns': [{'name': 'a'},
#         {'name': 'customer_id'},
#         {'name': 'a'},
#         {'name': 'region'},
#         {'name': 'a'},
#         {'name': 'total_spend'}]},
#       'having': None,
#       'order_by': None}}]},
#   {'id': 'node_000041',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 51,
#     'col_start': 0,
#     'line_end': 64,
#     'col_end': 5,
#     'byte_start': 1496,
#     'byte_end': 1886},
#    'comments': ['/* Step 2a: Merge with loyalty data */'],
#    'type': 'SasProcStep',
#    'procedure_name': 'sql',
#    'options': {},
#    'statements': [{'id': 'node_000040',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 52,
#       'col_start': 4,
#       'line_end': 52,
#       'col_end': 10,
#       'byte_start': 1510,
#       'byte_end': 1516},
#      'type': 'SasProcSqlCreateTableStatement',
#      'table_name': 'customer_full_profile',
#      'table_options': None,
#      'select_statement': {'id': 'node_000039',
#       'level': 0,
#       'location': {'file': 'nested_test.sas',
#        'line_start': 53,
#        'col_start': 4,
#        'line_end': 63,
#        'col_end': 41,
#        'byte_start': 1552,
#        'byte_end': 1880},
#       'type': 'SasProcSqlSelectStatement',
#       'distinct': False,
#       'columns': [{'id': 'node_000035',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 54,
#          'col_start': 8,
#          'line_end': 54,
#          'col_end': 12,
#          'byte_start': 1568,
#          'byte_end': 1572},
#         'type': 'SasCalculatedColumn',
#         'expression': 'c . *',
#         'alias': None,
#         'format': None,
#         'length': None,
#         'raw_tokens': ['c', '.', '*']},
#        {'id': 'node_000036',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 55,
#          'col_start': 8,
#          'line_end': 55,
#          'col_end': 25,
#          'byte_start': 1581,
#          'byte_end': 1598},
#         'type': 'SasSimpleColumn',
#         'expression': 'l . loyalty_points',
#         'alias': None,
#         'format': None,
#         'length': None,
#         'raw_tokens': ['l', '.', 'loyalty_points']},
#        {'id': 'node_000037',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 56,
#          'col_start': 8,
#          'line_end': 61,
#          'col_end': 8,
#          'byte_start': 1607,
#          'byte_end': 1785},
#         'type': 'SasCaseColumn',
#         'when_clauses': [{'condition': 'l . loyalty_points >= 5000',
#           'then_value': "'GOLD'"},
#          {'condition': 'l . loyalty_points >= 1000',
#           'then_value': "'SILVER'"}],
#         'else_value': "'BRONZE'",
#         'alias': 'loyalty_tier',
#         'format': None,
#         'length': None}],
#       'into': None,
#       'from': {'id': 'node_000038',
#        'level': 0,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 61,
#         'col_start': 4,
#         'line_end': 61,
#         'col_end': 8,
#         'byte_start': 1781,
#         'byte_end': 1785},
#        'type': 'SasProcSqlFromClause',
#        'main_table': {'type': 'SasProcSqlTableRef',
#         'table_name': 'customer_txn_summary',
#         'alias': 'c'},
#        'joins': [{'type': 'SasProcSqlJoin',
#          'join_type': 'LEFT',
#          'table': {'type': 'SasProcSqlTableRef',
#           'table_name': 'loyalty_clean',
#           'alias': 'l'},
#          'on_condition': {'type': 'SasProcSqlJoinCondition',
#           'condition': 'c . customer_id = l . customer_id'}}]},
#       'where': None,
#       'group_by': None,
#       'having': None,
#       'order_by': None}}]},
#   {'id': 'node_000054',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 67,
#     'col_start': 0,
#     'line_end': 84,
#     'col_end': 5,
#     'byte_start': 1927,
#     'byte_end': 2465},
#    'comments': ['/* Step 3: Create customer segments */'],
#    'type': 'SasProcStep',
#    'procedure_name': 'sql',
#    'options': {},
#    'statements': [{'id': 'node_000053',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 68,
#       'col_start': 4,
#       'line_end': 68,
#       'col_end': 10,
#       'byte_start': 1941,
#       'byte_end': 1947},
#      'type': 'SasProcSqlCreateTableStatement',
#      'table_name': 'customer_segments',
#      'table_options': None,
#      'select_statement': {'id': 'node_000052',
#       'level': 0,
#       'location': {'file': 'nested_test.sas',
#        'line_start': 69,
#        'col_start': 4,
#        'line_end': 83,
#        'col_end': 60,
#        'byte_start': 1979,
#        'byte_end': 2459},
#       'type': 'SasProcSqlSelectStatement',
#       'distinct': False,
#       'columns': [{'id': 'node_000042',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 70,
#          'col_start': 8,
#          'line_end': 70,
#          'col_end': 20,
#          'byte_start': 1995,
#          'byte_end': 2007},
#         'type': 'SasSimpleColumn',
#         'expression': 'customer_id',
#         'alias': None,
#         'format': None,
#         'length': None,
#         'raw_tokens': ['customer_id']},
#        {'id': 'node_000043',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 71,
#          'col_start': 8,
#          'line_end': 71,
#          'col_end': 15,
#          'byte_start': 2016,
#          'byte_end': 2023},
#         'type': 'SasSimpleColumn',
#         'expression': 'region',
#         'alias': None,
#         'format': None,
#         'length': None,
#         'raw_tokens': ['region']},
#        {'id': 'node_000044',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 72,
#          'col_start': 8,
#          'line_end': 72,
#          'col_end': 20,
#          'byte_start': 2032,
#          'byte_end': 2044},
#         'type': 'SasSimpleColumn',
#         'expression': 'total_spend',
#         'alias': None,
#         'format': None,
#         'length': None,
#         'raw_tokens': ['total_spend']},
#        {'id': 'node_000045',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 73,
#          'col_start': 8,
#          'line_end': 73,
#          'col_end': 18,
#          'byte_start': 2053,
#          'byte_end': 2063},
#         'type': 'SasSimpleColumn',
#         'expression': 'txn_total',
#         'alias': None,
#         'format': None,
#         'length': None,
#         'raw_tokens': ['txn_total']},
#        {'id': 'node_000046',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 74,
#          'col_start': 8,
#          'line_end': 74,
#          'col_end': 21,
#          'byte_start': 2072,
#          'byte_end': 2085},
#         'type': 'SasSimpleColumn',
#         'expression': 'loyalty_tier',
#         'alias': None,
#         'format': None,
#         'length': None,
#         'raw_tokens': ['loyalty_tier']},
#        {'id': 'node_000047',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 75,
#          'col_start': 8,
#          'line_end': 79,
#          'col_end': 29,
#          'byte_start': 2094,
#          'byte_end': 2274},
#         'type': 'SasCaseColumn',
#         'when_clauses': [{'condition': 'total_spend > & seg_threshold',
#           'then_value': "'HIGH'"},
#          {'condition': 'total_spend > ( & seg_threshold / 2 )',
#           'then_value': "'MEDIUM'"}],
#         'else_value': "'LOW'",
#         'alias': 'spend_segment',
#         'format': None,
#         'length': None},
#        {'id': 'node_000048',
#         'level': 0,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 80,
#          'col_start': 8,
#          'line_end': 81,
#          'col_end': 8,
#          'byte_start': 2283,
#          'byte_end': 2316},
#         'type': 'SasCalculatedColumn',
#         'expression': 'count ( * )',
#         'alias': 'segment_size',
#         'format': None,
#         'length': None,
#         'raw_tokens': ['count', '(', '*', ')']}],
#       'into': None,
#       'from': {'id': 'node_000049',
#        'level': 0,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 81,
#         'col_start': 4,
#         'line_end': 81,
#         'col_end': 8,
#         'byte_start': 2312,
#         'byte_end': 2316},
#        'type': 'SasProcSqlFromClause',
#        'main_table': {'type': 'SasProcSqlTableRef',
#         'table_name': 'customer_full_profile',
#         'alias': None},
#        'joins': []},
#       'where': None,
#       'group_by': {'id': 'node_000050',
#        'level': 0,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 82,
#         'col_start': 4,
#         'line_end': 83,
#         'col_end': 9,
#         'byte_start': 2343,
#         'byte_end': 2408},
#        'type': 'SasProcSqlGroupByClause',
#        'columns': [{'name': 'spend_segment'},
#         {'name': 'region'},
#         {'name': 'loyalty_tier'}]},
#       'having': None,
#       'order_by': {'id': 'node_000051',
#        'level': 0,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 83,
#         'col_start': 4,
#         'line_end': 83,
#         'col_end': 60,
#         'byte_start': 2403,
#         'byte_end': 2459},
#        'type': 'SasProcSqlOrderByClause',
#        'columns': [{'name': 'region', 'direction': 'ASC'},
#         {'name': 'loyalty_tier', 'direction': 'ASC'},
#         {'name': 'spend_segment', 'direction': 'ASC'}]}}}]},
#   {'id': 'node_000056',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 87,
#     'col_start': 0,
#     'line_end': 93,
#     'col_end': 4,
#     'byte_start': 2503,
#     'byte_end': 2807},
#    'comments': ['/* Step 4: Create summary report */'],
#    'type': 'SasProcStep',
#    'procedure_name': 'summary',
#    'options': {},
#    'statements': [{'id': 'node_000055',
#      'level': 0,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 89,
#       'col_start': 4,
#       'line_end': 89,
#       'col_end': 30,
#       'byte_start': 2594,
#       'byte_end': 2620},
#      'type': 'SasProcVarStatement',
#      'variables': ['total_spend', 'txn_total']}]},
#   {'id': 'node_000067',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 96,
#     'col_start': 0,
#     'line_end': 112,
#     'col_end': 6,
#     'byte_start': 2854,
#     'byte_end': 3396},
#    'comments': ['/* Step 5: Define report formatting macro */'],
#    'type': 'SasMacroDef',
#    'macro_name': 'format_report',
#    'parameters': [{'name': 'input_ds', 'default_value': None},
#     {'name': 'output_ds', 'default_value': None},
#     {'name': 'title_text', 'default_value': None}],
#    'macro_body': [{'id': 'node_000064',
#      'level': 1,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 97,
#       'col_start': 4,
#       'line_end': 104,
#       'col_end': 8,
#       'byte_start': 2913,
#       'byte_end': 3162},
#      'type': 'SasDataStep',
#      'name': 'unnamed',
#      'datasets_out': [],
#      'statements': [{'id': 'node_000057',
#        'level': 1,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 98,
#         'col_start': 8,
#         'line_end': 98,
#         'col_end': 22,
#         'byte_start': 2938,
#         'byte_end': 2952},
#        'type': 'SasSetStatement',
#        'datasets': []},
#       {'id': 'node_000058',
#        'level': 1,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 99,
#         'col_start': 8,
#         'line_end': 99,
#         'col_end': 37,
#         'byte_start': 2961,
#         'byte_end': 2990},
#        'type': 'SasAssignmentStatement',
#        'variable': 'report_title',
#        'expression': '" & title_text "'},
#       {'id': 'node_000059',
#        'level': 1,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 100,
#         'col_start': 8,
#         'line_end': 100,
#         'col_end': 30,
#         'byte_start': 2999,
#         'byte_end': 3021},
#        'type': 'SasAssignmentStatement',
#        'variable': 'report_date',
#        'expression': 'today ( )'},
#       {'id': 'node_000060',
#        'level': 1,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 101,
#         'col_start': 8,
#         'line_end': 101,
#         'col_end': 34,
#         'byte_start': 3030,
#         'byte_end': 3056},
#        'type': 'SasUnknownStatement',
#        'kind': 'unknown',
#        'text': 'formatreport_datedate9.;'},
#       {'id': 'node_000063',
#        'level': 1,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 102,
#         'col_start': 8,
#         'line_end': 102,
#         'col_end': 10,
#         'byte_start': 3065,
#         'byte_end': 3067},
#        'type': 'SasIfStatement',
#        'condition': 'total_segment_revenue > 100000',
#        'then_block': {'id': 'node_000061',
#         'level': 1,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 102,
#          'col_start': 47,
#          'line_end': 102,
#          'col_end': 65,
#          'byte_start': 3104,
#          'byte_end': 3122},
#         'type': 'SasAssignmentStatement',
#         'variable': 'highlight',
#         'expression': "'YES'"},
#        'else_block': {'id': 'node_000062',
#         'level': 1,
#         'location': {'file': 'nested_test.sas',
#          'line_start': 103,
#          'col_start': 13,
#          'line_end': 103,
#          'col_end': 30,
#          'byte_start': 3136,
#          'byte_end': 3153},
#         'type': 'SasAssignmentStatement',
#         'variable': 'highlight',
#         'expression': "'NO'"}}]},
#     {'id': 'node_000066',
#      'level': 1,
#      'location': {'file': 'nested_test.sas',
#       'line_start': 106,
#       'col_start': 4,
#       'line_end': 111,
#       'col_end': 8,
#       'byte_start': 3168,
#       'byte_end': 3389},
#      'type': 'SasProcStep',
#      'procedure_name': 'print',
#      'options': {},
#      'statements': [{'id': 'node_000065',
#        'level': 1,
#        'location': {'file': 'nested_test.sas',
#         'line_start': 108,
#         'col_start': 8,
#         'line_end': 110,
#         'col_end': 55,
#         'byte_start': 3233,
#         'byte_end': 3380},
#        'type': 'SasProcVarStatement',
#        'variables': ['region',
#         'spend_segment',
#         'loyalty_tier',
#         'total_segment_revenue',
#         'total_txn_revenue',
#         'avg_customer_spend',
#         'avg_txn_value',
#         'highlight']}]}]},
#   {'id': 'node_000068',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 115,
#     'col_start': 0,
#     'line_end': 115,
#     'col_end': 101,
#     'byte_start': 3438,
#     'byte_end': 3539},
#    'comments': ['/* Step 6: Generate formatted report */'],
#    'type': 'SasMacroCall',
#    'macro_name': 'format_report',
#    'arguments': {'positional': ['segment_summary',
#      ',',
#      'final_report',
#      ',',
#      'Customer Segment Analysis with Loyalty & Transactions'],
#     'keyword': {},
#     'raw_order': ['segment_summary',
#      ',',
#      'final_report',
#      ',',
#      'Customer Segment Analysis with Loyalty & Transactions']}},
#   {'id': 'node_000069',
#    'level': 0,
#    'location': {'file': 'nested_test.sas',
#     'line_start': 118,
#     'col_start': 0,
#     'line_end': 122,
#     'col_end': 4,
#     'byte_start': 3570,
#     'byte_end': 3676},
#    'comments': ['/* Step 7: Export results */'],
#    'type': 'SasProcStep',
#    'procedure_name': 'export',
#    'options': {'dbms': 'xlsx'},
#    'statements': []}]}

# %%
from sas_ast_walker import extract_datasets_from_ast

results= extract_datasets_from_ast(result)

# %%
results["dataset_details"]
# Out:
# [DatasetInfo(name='customers_clean', type='derived', operation='data_step', location={'file': 'nested_test.sas', 'line_start': 9, 'col_start': 0, 'line_end': 16, 'col_end': 4, 'byte_start': 320, 'byte_end': 583}, node_id='node_000011'),
#  DatasetInfo(name='raw.customer_data', type='source', operation='set_statement', location={'file': 'nested_test.sas', 'line_start': 10, 'col_start': 4, 'line_end': 10, 'col_end': 26, 'byte_start': 346, 'byte_end': 368}, node_id='node_000003'),
#  DatasetInfo(name='transactions_clean', type='derived', operation='data_step', location={'file': 'nested_test.sas', 'line_start': 19, 'col_start': 0, 'line_end': 25, 'col_end': 4, 'byte_start': 624, 'byte_end': 817}, node_id='node_000018'),
#  DatasetInfo(name='raw.transaction_data', type='source', operation='set_statement', location={'file': 'nested_test.sas', 'line_start': 20, 'col_start': 4, 'line_end': 20, 'col_end': 29, 'byte_start': 653, 'byte_end': 678}, node_id='node_000012'),
#  DatasetInfo(name='loyalty_clean', type='derived', operation='data_step', location={'file': 'nested_test.sas', 'line_start': 28, 'col_start': 0, 'line_end': 32, 'col_end': 4, 'byte_start': 862, 'byte_end': 992}, node_id='node_000023'),
#  DatasetInfo(name='raw.loyalty_data', type='source', operation='set_statement', location={'file': 'nested_test.sas', 'line_start': 29, 'col_start': 4, 'line_end': 29, 'col_end': 25, 'byte_start': 886, 'byte_end': 907}, node_id='node_000019'),
#  DatasetInfo(name='customer_txn_summary', type='derived', operation='proc_sql_create_table', location={'file': 'nested_test.sas', 'line_start': 36, 'col_start': 4, 'line_end': 36, 'col_end': 10, 'byte_start': 1058, 'byte_end': 1064}, node_id='node_000033'),
#  DatasetInfo(name='customers_clean', type='reference', operation='from_clause_main', location={'file': 'nested_test.sas', 'line_start': 44, 'col_start': 4, 'line_end': 44, 'col_end': 8, 'byte_start': 1298, 'byte_end': 1302}, node_id='node_000030'),
#  DatasetInfo(name='transactions_clean', type='reference', operation='from_clause_join', location={'file': 'nested_test.sas', 'line_start': 44, 'col_start': 4, 'line_end': 44, 'col_end': 8, 'byte_start': 1298, 'byte_end': 1302}, node_id='node_000030'),
#  DatasetInfo(name='customer_full_profile', type='derived', operation='proc_sql_create_table', location={'file': 'nested_test.sas', 'line_start': 52, 'col_start': 4, 'line_end': 52, 'col_end': 10, 'byte_start': 1510, 'byte_end': 1516}, node_id='node_000040'),
#  DatasetInfo(name='customer_txn_summary', type='reference', operation='from_clause_main', location={'file': 'nested_test.sas', 'line_start': 61, 'col_start': 4, 'line_end': 61, 'col_end': 8, 'byte_start': 1781, 'byte_end': 1785}, node_id='node_000038'),
#  DatasetInfo(name='loyalty_clean', type='reference', operation='from_clause_join', location={'file': 'nested_test.sas', 'line_start': 61, 'col_start': 4, 'line_end': 61, 'col_end': 8, 'byte_start': 1781, 'byte_end': 1785}, node_id='node_000038'),
#  DatasetInfo(name='customer_segments', type='derived', operation='proc_sql_create_table', location={'file': 'nested_test.sas', 'line_start': 68, 'col_start': 4, 'line_end': 68, 'col_end': 10, 'byte_start': 1941, 'byte_end': 1947}, node_id='node_000053'),
#  DatasetInfo(name='customer_full_profile', type='reference', operation='from_clause_main', location={'file': 'nested_test.sas', 'line_start': 81, 'col_start': 4, 'line_end': 81, 'col_end': 8, 'byte_start': 2312, 'byte_end': 2316}, node_id='node_000049'),
#  DatasetInfo(name='unnamed', type='derived', operation='data_step', location={'file': 'nested_test.sas', 'line_start': 97, 'col_start': 4, 'line_end': 104, 'col_end': 8, 'byte_start': 2913, 'byte_end': 3162}, node_id='node_000064'),
#  DatasetInfo(name='segment_summary', type='reference', operation='macro_call_argument', location={'file': 'nested_test.sas', 'line_start': 115, 'col_start': 0, 'line_end': 115, 'col_end': 101, 'byte_start': 3438, 'byte_end': 3539}, node_id='node_000068'),
#  DatasetInfo(name='final_report', type='reference', operation='macro_call_argument', location={'file': 'nested_test.sas', 'line_start': 115, 'col_start': 0, 'line_end': 115, 'col_end': 101, 'byte_start': 3438, 'byte_end': 3539}, node_id='node_000068'),
#  DatasetInfo(name='Customer Segment Analysis with Loyalty & Transactions', type='reference', operation='macro_call_argument', location={'file': 'nested_test.sas', 'line_start': 115, 'col_start': 0, 'line_end': 115, 'col_end': 101, 'byte_start': 3438, 'byte_end': 3539}, node_id='node_000068')]

# %%
from enhanced_ast_walker import extract_comprehensive_context

info=extract_comprehensive_context(result)

# %%
info
# Out:
# LineageExtractionContext(data_steps=[DataStepContext(step_id='node_000011', step_name='customers_clean', input_datasets=['raw.customer_data'], output_datasets=['customers_clean'], transformations=[TransformationDetail(transformation_type='filter', description="wherestatus='ACTIVE';", variables_involved=['wherestatus', 'active', ';'], logic="wherestatus='ACTIVE';", location={'file': 'nested_test.sas', 'line_start': 11, 'col_start': 4, 'line_end': 11, 'col_end': 28, 'byte_start': 373, 'byte_end': 397}), TransformationDetail(transformation_type='assignment', description='total_spend = sum ( spend_cat1 , spend_cat2 , spend_cat3 )', variables_involved=['total_spend'], logic='total_spend = sum ( spend_cat1 , spend_cat2 , spend_cat3 )', location={'file': 'nested_test.sas', 'line_start': 12, 'col_start': 4, 'line_end': 12, 'col_end': 58, 'byte_start': 402, 'byte_end': 456}), TransformationDetail(transformation_type='conditional', description='if total_spend < 0 then total_spend = 0', variables_involved=['total_spend'], logic='if total_spend < 0 then total_spend = 0', location={'file': 'nested_test.sas', 'line_start': 13, 'col_start': 4, 'line_end': 13, 'col_end': 6, 'byte_start': 461, 'byte_end': 463}), TransformationDetail(transformation_type='conditional', description="if missing ( region ) then region = 'UNKNOWN'", variables_involved=[], logic="if missing ( region ) then region = 'UNKNOWN'", location={'file': 'nested_test.sas', 'line_start': 14, 'col_start': 4, 'line_end': 14, 'col_end': 6, 'byte_start': 506, 'byte_end': 508})], filtering_logic=["wherestatus='ACTIVE';"], variable_derivations={'total_spend': 'sum ( spend_cat1 , spend_cat2 , spend_cat3 )'}, conditional_logic=['if total_spend < 0 then total_spend = 0', "if missing ( region ) then region = 'UNKNOWN'"], location={'file': 'nested_test.sas', 'line_start': 9, 'col_start': 0, 'line_end': 16, 'col_end': 4, 'byte_start': 320, 'byte_end': 583}, sequence_order=1), DataStepContext(step_id='node_000018', step_name='transactions_clean', input_datasets=['raw.transaction_data'], output_datasets=['transactions_clean'], transformations=[TransformationDetail(transformation_type='filter', description="wheretxn_status='SUCCESS';", variables_involved=['wheretxn_status', ';', 'success'], logic="wheretxn_status='SUCCESS';", location={'file': 'nested_test.sas', 'line_start': 21, 'col_start': 4, 'line_end': 21, 'col_end': 33, 'byte_start': 683, 'byte_end': 712}), TransformationDetail(transformation_type='assignment', description='txn_month = month ( txn_date )', variables_involved=['txn_month'], logic='txn_month = month ( txn_date )', location={'file': 'nested_test.sas', 'line_start': 22, 'col_start': 4, 'line_end': 22, 'col_end': 32, 'byte_start': 717, 'byte_end': 745}), TransformationDetail(transformation_type='assignment', description='txn_year = year ( txn_date )', variables_involved=['txn_year'], logic='txn_year = year ( txn_date )', location={'file': 'nested_test.sas', 'line_start': 23, 'col_start': 4, 'line_end': 23, 'col_end': 31, 'byte_start': 750, 'byte_end': 777}), TransformationDetail(transformation_type='conditional', description='if amount < 0 then amount = 0', variables_involved=['amount'], logic='if amount < 0 then amount = 0', location={'file': 'nested_test.sas', 'line_start': 24, 'col_start': 4, 'line_end': 24, 'col_end': 6, 'byte_start': 782, 'byte_end': 784})], filtering_logic=["wheretxn_status='SUCCESS';"], variable_derivations={'txn_month': 'month ( txn_date )', 'txn_year': 'year ( txn_date )'}, conditional_logic=['if amount < 0 then amount = 0'], location={'file': 'nested_test.sas', 'line_start': 19, 'col_start': 0, 'line_end': 25, 'col_end': 4, 'byte_start': 624, 'byte_end': 817}, sequence_order=2), DataStepContext(step_id='node_000023', step_name='loyalty_clean', input_datasets=['raw.loyalty_data'], output_datasets=['loyalty_clean'], transformations=[TransformationDetail(transformation_type='filter', description='whereenrolled=1;', variables_involved=['1;', 'whereenro ...

# %%
from llm_lineage_generator import generate_lineage_with_llm

lin=generate_lineage_with_llm(info)

# %%
lin
# Out:
# DatasetLineage(nodes=[LineageNode(dataset_name='raw.customer_data', dataset_type='source', created_by='Source system extract', inputs=[], transformations=[], variables_created=[], business_logic='Raw customer master data containing customer demographics, status, and spending categories.'), LineageNode(dataset_name='customers_clean', dataset_type='intermediate', created_by='DATA step - customers_clean', inputs=['raw.customer_data'], transformations=["Filter records where status = 'ACTIVE'", 'Calculate total_spend = sum(spend_cat1, spend_cat2, spend_cat3)', 'If total_spend < 0 then set to 0', "If region is missing then set to 'UNKNOWN'"], variables_created=['total_spend', 'region (default UNKNOWN)'], business_logic='Active customers with cleaned and standardized spend and region information.'), LineageNode(dataset_name='raw.transaction_data', dataset_type='source', created_by='Source system extract', inputs=[], transformations=[], variables_created=[], business_logic='Raw transaction records including transaction date, amount, and status.'), LineageNode(dataset_name='transactions_clean', dataset_type='intermediate', created_by='DATA step - transactions_clean', inputs=['raw.transaction_data'], transformations=["Filter records where txn_status = 'SUCCESS'", 'Derive txn_month = month(txn_date)', 'Derive txn_year = year(txn_date)', 'If amount < 0 then set to 0'], variables_created=['txn_month', 'txn_year'], business_logic='Successful transactions with derived month/year fields and non-negative amounts.'), LineageNode(dataset_name='raw.loyalty_data', dataset_type='source', created_by='Source system extract', inputs=[], transformations=[], variables_created=[], business_logic='Raw loyalty program data including enrollment status and loyalty points.'), LineageNode(dataset_name='loyalty_clean', dataset_type='intermediate', created_by='DATA step - loyalty_clean', inputs=['raw.loyalty_data'], transformations=['Filter records where enrolled = 1', 'If loyalty_points is missing then set to 0'], variables_created=['loyalty_points (default 0)'], business_logic='Enrolled loyalty program members with standardized loyalty points.'), LineageNode(dataset_name='customer_txn_summary', dataset_type='intermediate', created_by='PROC SQL - join customers_clean and transactions_clean', inputs=['customers_clean', 'transactions_clean'], transformations=['LEFT JOIN transactions_clean on customer_id', 'Group by customer_id, region, total_spend', 'Aggregate: count distinct txn_id as txn_count, sum(amount) as txn_total, avg(amount) as avg_txn_amount'], variables_created=['txn_count', 'txn_total', 'avg_txn_amount'], business_logic='Customer-level transaction summary combining customer profile with aggregated transaction metrics.'), LineageNode(dataset_name='customer_full_profile', dataset_type='intermediate', created_by='PROC SQL - join customer_txn_summary and loyalty_clean', inputs=['customer_txn_summary', 'loyalty_clean'], transformations=['LEFT JOIN loyalty_clean on customer_id', 'Include all customer_txn_summary fields', 'Add loyalty_points', 'Derive loyalty_tier via CASE: GOLD if points >= 5000, SILVER if >= 1000, else BRONZE'], variables_created=['loyalty_tier'], business_logic='Comprehensive customer profile including transaction metrics and loyalty program tier.'), LineageNode(dataset_name='customer_segments', dataset_type='final', created_by='PROC SQL - segment customer_full_profile', inputs=['customer_full_profile'], transformations=['Derive spend_segment via CASE: HIGH if total_spend > &seg_threshold, MEDIUM if > &seg_threshold/2, else LOW', 'Group by spend_segment, region, loyalty_tier', 'Aggregate: count(*) as segment_size'], variables_created=['spend_segment', 'segment_size'], business_logic='Customer segmentation dataset categorizing customers by spend level, region, and loyalty tier, with segment sizes.')], relationships=[LineageRelationship(source_dataset='raw.customer_data', target_dataset='customers_clean', transformation_type='data_step', tr ...

# %%
def print_lineage_analysis(lineage):
    """Print detailed lineage analysis"""

    print("=" * 80)
    print("📊 COMPREHENSIVE DATASET LINEAGE ANALYSIS")
    print("=" * 80)

    print(f"\n🔄 DATA FLOW OVERVIEW:")
    print(f"   {lineage.flow_description}")

    # Group nodes by type
    source_nodes = [n for n in lineage.nodes if n.dataset_type == 'source']
    intermediate_nodes = [n for n in lineage.nodes if n.dataset_type == 'intermediate']
    final_nodes = [n for n in lineage.nodes if n.dataset_type == 'final']

    print(f"\n📁 DATASET INVENTORY:")
    print(f"   📥 Sources: {len(source_nodes)}")
    print(f"   ⚙️  Intermediate: {len(intermediate_nodes)}")
    print(f"   🎯 Final: {len(final_nodes)}")

    print(f"\n🗂️  SOURCE DATASETS:")
    print("-" * 50)
    for node in source_nodes:
        print(f"  📥 {node.dataset_name}")
        print(f"     Purpose: {node.business_logic}")

    print(f"\n⚙️  INTERMEDIATE DATASETS:")
    print("-" * 50)
    for node in intermediate_nodes:
        print(f"  🔄 {node.dataset_name}")
        print(f"     Created by: {node.created_by}")
        print(f"     Input datasets: {', '.join(node.inputs)}")
        print(f"     New variables: {', '.join(node.variables_created) if node.variables_created else 'None'}")
        print(f"     Business purpose: {node.business_logic}")
        if node.transformations:
            print(f"     Key transformations:")
            for transform in node.transformations[:2]:  # Show first 2
                print(f"       • {transform}")
        print()

    print(f"🔗 DATA FLOW RELATIONSHIPS:")
    print("-" * 50)
    for rel in lineage.relationships:
        print(f"  {rel.source_dataset} ➜ {rel.target_dataset}")
        print(f"    Type: {rel.transformation_type}")
        print(f"    Process: {rel.transformation_description}")
        if rel.variables_passed:
            print(f"    Variables involved: {', '.join(rel.variables_passed[:3])}...")
        print()

    print(f"🧬 VARIABLE LINEAGE:")
    print("-" * 50)
    for var, sources in lineage.variable_lineage.items():
        print(f"  {var} ← derived from: {', '.join(sources)}")

    print(f"\n📈 BUSINESS INSIGHTS:")
    print("-" * 50)
    print("  🔍 Data Quality Steps:")
    print("    • Active customer filtering (status = 'ACTIVE')")
    print("    • Successful transaction filtering (txn_status = 'SUCCESS')")
    print("    • Negative value handling (total_spend < 0 → 0)")

    print("  🔗 Integration Points:")
    print("    • Customer-Transaction join on customer_id")
    print("    • Left join preserves all customers even without transactions")

    print("  📊 Key Business Metrics:")
    print("    • total_spend: Sum of all spending categories per customer")
    print("    • txn_count: Number of distinct transactions per customer")
    print("    • txn_total: Total transaction amount per customer")
    print("    • avg_txn_amount: Average transaction size per customer")

# %%
print_lineage_analysis(lin)
# Out:
# ================================================================================
# 📊 COMPREHENSIVE DATASET LINEAGE ANALYSIS
# ================================================================================
#
# 🔄 DATA FLOW OVERVIEW:
#    The data flow begins with three raw source datasets: customer_data, transaction_data, and loyalty_data. Each undergoes a cleaning step to filter relevant records and standardize variables, producing customers_clean, transactions_clean, and loyalty_clean. Customers_clean and transactions_clean are joined to create customer_txn_summary, which aggregates transaction metrics per customer. This summary is then joined with loyalty_clean to produce customer_full_profile, adding loyalty points and tier classification. Finally, customer_full_profile is segmented into customer_segments based on spend thresholds, region, and loyalty tier, with segment sizes calculated. Customer_segments serves as the final analytical dataset for segmentation analysis.
#
# 📁 DATASET INVENTORY:
#    📥 Sources: 3
#    ⚙️  Intermediate: 5
#    🎯 Final: 1
#
# 🗂️  SOURCE DATASETS:
# --------------------------------------------------
#   📥 raw.customer_data
#      Purpose: Raw customer master data containing customer demographics, status, and spending categories.
#   📥 raw.transaction_data
#      Purpose: Raw transaction records including transaction date, amount, and status.
#   📥 raw.loyalty_data
#      Purpose: Raw loyalty program data including enrollment status and loyalty points.
#
# ⚙️  INTERMEDIATE DATASETS:
# --------------------------------------------------
#   🔄 customers_clean
#      Created by: DATA step - customers_clean
#      Input datasets: raw.customer_data
#      New variables: total_spend, region (default UNKNOWN)
#      Business purpose: Active customers with cleaned and standardized spend and region information.
#      Key transformations:
#        • Filter records where status = 'ACTIVE'
#        • Calculate total_spend = sum(spend_cat1, spend_cat2, spend_cat3)
#
#   🔄 transactions_clean
#      Created by: DATA step - transactions_clean
#      Input datasets: raw.transaction_data
#      New variables: txn_month, txn_year
#      Business purpose: Successful transactions with derived month/year fields and non-negative amounts.
#      Key transformations:
#        • Filter records where txn_status = 'SUCCESS'
#        • Derive txn_month = month(txn_date)
#
#   🔄 loyalty_clean
#      Created by: DATA step - loyalty_clean
#      Input datasets: raw.loyalty_data
#      New variables: loyalty_points (default 0)
#      Business purpose: Enrolled loyalty program members with standardized loyalty points.
#      Key transformations:
#        • Filter records where enrolled = 1
#        • If loyalty_points is missing then set to 0
#
#   🔄 customer_txn_summary
#      Created by: PROC SQL - join customers_clean and transactions_clean
#      Input datasets: customers_clean, transactions_clean
#      New variables: txn_count, txn_total, avg_txn_amount
#      Business purpose: Customer-level transaction summary combining customer profile with aggregated transaction metrics.
#      Key transformations:
#        • LEFT JOIN transactions_clean on customer_id
#        • Group by customer_id, region, total_spend
#
#   🔄 customer_full_profile
#      Created by: PROC SQL - join customer_txn_summary and loyalty_clean
#      Input datasets: customer_txn_summary, loyalty_clean
#      New variables: loyalty_tier
#      Business purpose: Comprehensive customer profile including transaction metrics and loyalty program tier.
#      Key transformations:
#        • LEFT JOIN loyalty_clean on customer_id
#        • Include all customer_txn_summary fields
#
# 🔗 DATA FLOW RELATIONSHIPS:
# --------------------------------------------------
#   raw.customer_data ➜ customers_clean
#     Type: data_step
#     Process: Filtered active customers, calculated total spend, handled missing region values.
#     Variables involved: customer_id, region, spend_cat1...
#
#   raw.transaction_data ➜ transactions_clean
#     Type: data_step
#     Process: Filtered successful transactions, derived month/year, ensured non-negative amounts.
#     Variables involved: txn_id, customer_id, txn_date...
#
#   raw.loyalty_data ➜ loyalty_clean
#     Type: data_step
#     Process: Filtered enrolled members, defaulted missing loyalty points to 0.
#     Variables involved: customer_id, loyalty_points...
#
#   customers_clean ➜ customer_txn_summary
#     Type: sql_join
#     Process: LEFT JOIN with transactions_clean on customer_id, aggregated transaction counts, totals, and averages.
#     Variables involved: customer_id, region, total_spend...
#
#   transactions_clean ➜ customer_txn_summary
#     Type: sql_join
#     Process: Joined to customers_clean to provide transaction metrics per customer.
#     Variables involved: txn_id, amount...
#
#   customer_txn_summary ➜ customer_full_profile
#     Type: sql_join
#     Process: LEFT JOIN with loyalty_clean to add loyalty points and tier classification.
#     Variables involved: customer_id, region, total_spend...
#
#   loyalty_clean ➜ customer_full_profile
#     Type: sql_join
#     Process: Joined to customer_txn_summary to enrich with loyalty program data.
#     Variables involved: loyalty_points...
#
#   customer_full_profile ➜ customer_segments
#     Type: aggregation
#     Process: Derived spend segments, grouped by spend_segment, region, loyalty_tier, counted customers per segment.
#     Variables involved: customer_id, region, total_spend...
#
# 🧬 VARIABLE LINEAGE:
# --------------------------------------------------
#   total_spend ← derived from: spend_cat1, spend_cat2, spend_cat3
#   txn_month ← derived from: txn_date
#   txn_year ← derived from: txn_date
#   txn_count ← derived from: txn_id
#   txn_total ← derived from: amount
#   avg_txn_amount ← derived from: amount
#   loyalty_tier ← derived from: loyalty_points
#   spend_segment ← derived from: total_spend, seg_threshold
#   segment_size ← derived from: customer_id
#
# 📈 BUSINESS INSIGHTS:
# --------------------------------------------------
#   🔍 Data Quality Steps:
#     • Active customer filtering (status = 'ACTIVE')
#     • Successful transaction filtering (txn_status = 'SUCCESS')
#     • Negative value handling (total_spend < 0 → 0)
#   🔗 Integration Points:
#     • Customer-Transaction join on customer_id
#     • Left join preserves all customers even without transactions
#   📊 Key Business Metrics:
#     • total_spend: Sum of all spending categories per customer
#     • txn_count: Number of distinct transactions per customer
#     • txn_total: Total transaction amount per customer
#     • avg_txn_amount: Average transaction size per customer

# %%
from data_definition_generator import generate_data_definitions
source=r"/Users/skshahid/Downloads/code-translate-workflows-v2/sas-data-def"
data_def=generate_data_definitions(source, lin)
# Out:
# 📁 Found 3 CSV files in /Users/skshahid/Downloads/code-translate-workflows-v2/sas-data-def
# 🔗 Matched 3 CSV files to source datasets
# 📊 Analyzing Customer_Data__Acronyms_.csv...
# ✅ Generated definition for customer_data
# 📊 Analyzing Loyalty_Data__Acronyms_.csv...
# ✅ Generated definition for loyalty_data
# 📊 Analyzing Transaction_Data__Acronyms_.csv...
# ✅ Generated definition for transaction_data

# %%
data_def
# Out:
# DataDefinitionContext(table_definitions=[TableDefinition(table_name='customer_data', file_path='/Users/skshahid/Downloads/code-translate-workflows-v2/sas-data-def/Customer_Data__Acronyms_.csv', business_purpose='Stores raw customer master data including personal identifiers, status, regional allocation, and spending amounts across three categories. This table serves as the foundational dataset for customer analytics, segmentation, and reporting.', columns=[ColumnDefinition(column_name='CUST_ID', data_type='VARCHAR(7)', max_length=7, is_nullable=False, constraints=['PRIMARY KEY', 'UNIQUE'], description='Unique identifier assigned to each customer in the source system.', business_rules=['Must be unique across all records', "Format: 'CUST' followed by a 3-digit number"], sample_values=['CUST001', 'CUST002', 'CUST003']), ColumnDefinition(column_name='FNAME', data_type='VARCHAR(50)', max_length=6, is_nullable=False, constraints=[], description="Customer's first name as recorded in the source system.", business_rules=['Should contain only alphabetic characters (and possibly hyphens or apostrophes)', 'No numeric values except in test data'], sample_values=['Name1', 'Name2', 'Name3']), ColumnDefinition(column_name='LNAME', data_type='VARCHAR(50)', max_length=9, is_nullable=False, constraints=[], description="Customer's last name or surname as recorded in the source system.", business_rules=['Should contain only alphabetic characters (and possibly hyphens or apostrophes)'], sample_values=['Surname1', 'Surname2', 'Surname3']), ColumnDefinition(column_name='STAT', data_type='VARCHAR(8)', max_length=8, is_nullable=False, constraints=["CHECK (STAT IN ('ACTIVE', 'INACTIVE'))"], description='Current status of the customer account.', business_rules=["Allowed values: 'ACTIVE', 'INACTIVE'"], sample_values=['ACTIVE', 'INACTIVE']), ColumnDefinition(column_name='SPND_C1', data_type='INTEGER', max_length=None, is_nullable=False, constraints=['CHECK (SPND_C1 >= 0)'], description='Total spending by the customer in category 1.', business_rules=['Must be a non-negative integer', 'Represents monetary value in whole units (e.g., USD)'], sample_values=[158, 610, 781]), ColumnDefinition(column_name='SPND_C2', data_type='INTEGER', max_length=None, is_nullable=False, constraints=['CHECK (SPND_C2 >= 0)'], description='Total spending by the customer in category 2.', business_rules=['Must be a non-negative integer', 'Represents monetary value in whole units (e.g., USD)'], sample_values=[216, 323, 437]), ColumnDefinition(column_name='SPND_C3', data_type='INTEGER', max_length=None, is_nullable=False, constraints=['CHECK (SPND_C3 >= 0)'], description='Total spending by the customer in category 3.', business_rules=['Must be a non-negative integer', 'Represents monetary value in whole units (e.g., USD)'], sample_values=[90, 59, 11]), ColumnDefinition(column_name='REGN', data_type='VARCHAR(5)', max_length=5, is_nullable=True, constraints=["CHECK (REGN IN ('NORTH', 'SOUTH', 'EAST', 'WEST') OR REGN IS NULL)"], description='Geographic region associated with the customer.', business_rules=["Allowed values: 'NORTH', 'SOUTH', 'EAST', 'WEST'", 'May be null if region is unknown or not assigned'], sample_values=['SOUTH', 'NORTH', 'WEST']), ColumnDefinition(column_name='JDATE', data_type='DATE', max_length=None, is_nullable=False, constraints=[], description='Date the customer joined or was registered in the system.', business_rules=['Must be a valid date in YYYY-MM-DD format', 'Cannot be a future date'], sample_values=['2020-01-01', '2020-03-31', '2020-06-29'])], primary_keys=['CUST_ID'], foreign_keys=[{'column': 'REGN', 'references': 'region_lookup.region_code', 'description': 'Reference to region lookup table for standardized region names or codes'}], indexes=['STAT', 'REGN', 'JDATE'], row_count=20, data_quality_notes=['CUST_ID is unique and non-null, suitable as a primary key.', 'REGN has 15% null values, which may indicate missing regional assignments.', "STAT contains on ...
